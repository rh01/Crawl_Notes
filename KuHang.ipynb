# %%
import requests
payload = {
'revAvailabilitySearch.SearchInfo.AdultCount':'1',
'revAvailabilitySearch.SearchInfo.ChildrenCount':'0',
'revAvailabilitySearch.SearchInfo.InfantCount':'0',
'revAvailabilitySearch.SearchInfo.Direction':'Return',
'revAvailabilitySearch.SearchInfo.PromoCode':'',
'revAvailabilitySearch.SearchInfo.SalesCode':'',
'revAvailabilitySearch.SearchInfo.SearchStations[0].DepartureStationCode':'NRT',
'revAvailabilitySearch.SearchInfo.SearchStations[0].ArrivalStationCode':'TPE',
'revAvailabilitySearch.SearchInfo.SearchStations[0].DepartureDate':'02/02/2017',
'revAvailabilitySearch.SearchInfo.SearchStations[1].DepartureStationCode':'TPE',
'revAvailabilitySearch.SearchInfo.SearchStations[1].ArrivalStationCode':'NRT',
'revAvailabilitySearch.SearchInfo.SearchStations[1].DepartureDate':'02/02/2017',
}

rs = requests.session()
res = requests.post('http://makeabooking.flyscoot.com/Book/?culture=zh-cn', data = payload) #由于做查询，所以是利用post方法
res2 = rs.get('http://makeabooking.flyscoot.com/Flight/Select')
print res2.text
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <script src="//cdn.optimizely.com/js/2329790140.js"></script>
#         <meta charset="utf-8">
#         <meta name="description" content="Scoot with us and book your cheap flights online. Enjoy your holiday with last minute air tickets to and from international destinations. Book now!">
#         <title>Scoot Flight Search</title>
#         <link rel="shortcut icon" href="/images/favicon.ico" type="image/x-icon">
#         <link href="/css/one.css?v=QLwnAphxCXN3swECfSUumnRpMMpEnFIHg7N6_v9godg1" rel="stylesheet"/>
#
#         <link href="/css/Layouts.css?v=vKYxZ9BLroN2C0EEBOo7nS7IsKJ1xFn6XQZLATY7Sto1" rel="stylesheet"/>
#
#         <script src="/js/one.js?v=rwNAygpGx5unlMi9HkURG3toR6f0_aDuQmuuSt0rGgc1"></script>
# <script src="/js/common.js?v=JohHsZdrbYPxBM19_G97olO83i43FJHtZgj2N8rja5o1"></script>
# <script src="/js/search.js?v=LyloqyKNiTR5ehm-0NlGBmVEg5k7idZrw5IhUQcxfWY1"></script>
#
# ...
